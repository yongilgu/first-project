# %%
from IPython.core.display import display, HTML
# 노트북 컨테이너 크기 조절
display(HTML("<style>#notebook-container {width: 90% !important; }</style>"))
# 마크다운 폰트
display(HTML("<style>.rendered_html{font-family: 'D2Coding'; font-size: 16pt; line-height: 140%;}</style>"))
# DataFrame 테이블 폰트
display(HTML("<style>.rendered_html table{font-family: 'D2Coding'; font-size: 16pt; line-height: 140%;}</style>"))
# 출력창 폰트
display(HTML("<style>pre{font-family: 'D2Coding', font-size: 16pt;}.rendered_html>ul>li{margin: 10px}</style>"))
display(HTML("<style>div.output_area>pre, div.output_subarea>pre{font-size: 16pt !important; line-height: 140%;}</style>"))
# 코드셀 폰트
display(HTML("<style> .CodeMirror pre {font-family: 'D2Coding'; font-size: 18pt !important; line-height: 140%;}</style>"))
# Out:
# <style>#notebook-container {width: 90% !important; }</style>
# <style>.rendered_html{font-family: 'D2Coding'; font-size: 16pt; line-height: 140%;}</style>
# <style>.rendered_html table{font-family: 'D2Coding'; font-size: 16pt; line-height: 140%;}</style>
# <style>pre{font-family: 'D2Coding', font-size: 16pt;}.rendered_html>ul>li{margin: 10px}</style>
# <style>div.output_area>pre, div.output_subarea>pre{font-size: 16pt !important; line-height: 140%;}</style>
# <style> .CodeMirror pre {font-family: 'D2Coding'; font-size: 18pt !important; line-height: 140%;}</style>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family='NanumGothic') # 나눔 고딕 폰트를 설정 -> fonf family 
plt.rcParams['axes.unicode_minus'] = False # - 출력

# %%
np.random.seed(0)
df = pd.DataFrame({
    'A' : np.arange(10, 20),
    'B' : np.random.randint(100, 200, 10)
})

# %% [markdown]
# # Pandas Plot
# - Index : X축
# - Value : Y축
# - Columns : 그래프

# %%
df['A'].plot(kind='line') # Line Plot 기본
# 그래프 유형은 kind 옵션의 값을 수정
df['A'].plot(kind='bar') # Bar Plot

# %%
# 1개의 컬럼 -> 1개의 라인(그래프)
df.plot(kind='line') # 같은 Y축을 공유 -> 컬럼간 스케일 차이가 크면 그래프가 이상함

# %%
df = pd.read_excel('data/seoul_transportation.xlsx', engine='openpyxl')
df
# Out:
#     대중교통구분    노선명      년월   승차총승객수
# 0      지하철    1호선  201711  8633618
# 1      지하철    1호선  201712  8737235
# 2      지하철    1호선  201801  8145989
# 3      지하철    1호선  201802  7273309
# 4      지하철    1호선  201803  8692551
# ..     ...    ...     ...      ...
# 596    지하철  우이신설선  201901  1263643
# 597    지하철  우이신설선  201902  1102109
# 598    지하철  우이신설선  201903  1402393
# 599    지하철  우이신설선  201904  1403115
# 600    지하철  우이신설선  201905  1469681
#
# [601 rows x 4 columns]

# %%
# 년월 : index, 노선명 : columns
df_pv = df.pivot_table(index='년월', columns='노선명', values='승차총승객수') / 10000
df_pv
# Out:
# 노선명          1호선        2호선        3호선        4호선        5호선        6호선  \
# 년월
# 201711  863.3618  4731.0952  1754.5987  1841.9611  1865.6464  1113.2866
# 201712  873.7235  4828.8516  1767.3756  1856.6142  1878.2771  1102.7361
# 201801  814.5989  4588.7302  1653.3633  1680.4039  1782.1984  1013.2175
# 201802  727.3309  4024.1730  1466.7088  1486.6104  1551.2971   900.6419
# 201803  869.2551  4903.3111  1796.4288  1886.9501  1924.1969  1149.6844
# 201804  827.5767  4727.3448  1742.8342  1816.8382  1897.3480  1110.8151
# 201805  854.3247  4824.9398  1791.0425  1873.7401  1926.4990  1156.7943
# 201806  797.2991  4548.5568  1676.4209  1739.8734  1801.4833  1060.2634
# 201807  815.0061  4735.6791  1714.6429  1713.2221  1827.6689  1063.2495
# 201808  793.0624  4561.0483  1656.2841  1633.6896  1760.0571  1022.9063
# 201809  787.6712  4260.7084  1602.9202  1617.8231  1683.3876  1018.5000
# 201810  878.3242  4834.3358  1802.8183  1851.5346  1927.7024  1181.1629
# ...

# %%
df_pv['2호선'].plot(figsize=(15, 5), ylabel='승차총승객수(단위:만명)', title='2호선 승차총승객수')
plt.savefig('2호선 승차 총승객수')

# %%
from matplotlib import font_manager
font_manager.findSystemFonts() # 설치된 폰트 목록 조회 
font_manager.FontProperties(fname='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf').get_name()
# 'NanumGothic'
# Out:
# 'NanumBarunGothic'

# %%
plt.rc('font', family='NanumBarunGothic') # 나눔 고딕 폰트를 설정 -> fonf family 
plt.rcParams['axes.unicode_minus'] = False # - 출력

# %%
df_pv.plot(figsize=(20, 5))

# %%
df_pv
# Out:
# 노선명          1호선        2호선        3호선        4호선        5호선        6호선  \
# 년월
# 201711  863.3618  4731.0952  1754.5987  1841.9611  1865.6464  1113.2866
# 201712  873.7235  4828.8516  1767.3756  1856.6142  1878.2771  1102.7361
# 201801  814.5989  4588.7302  1653.3633  1680.4039  1782.1984  1013.2175
# 201802  727.3309  4024.1730  1466.7088  1486.6104  1551.2971   900.6419
# 201803  869.2551  4903.3111  1796.4288  1886.9501  1924.1969  1149.6844
# 201804  827.5767  4727.3448  1742.8342  1816.8382  1897.3480  1110.8151
# 201805  854.3247  4824.9398  1791.0425  1873.7401  1926.4990  1156.7943
# 201806  797.2991  4548.5568  1676.4209  1739.8734  1801.4833  1060.2634
# 201807  815.0061  4735.6791  1714.6429  1713.2221  1827.6689  1063.2495
# 201808  793.0624  4561.0483  1656.2841  1633.6896  1760.0571  1022.9063
# 201809  787.6712  4260.7084  1602.9202  1617.8231  1683.3876  1018.5000
# 201810  878.3242  4834.3358  1802.8183  1851.5346  1927.7024  1181.1629
# ...

# %%
pd.set_option('display.max_rows', N) # N개 이하 행일땐 생략하지 않음 
pd.set_option('display.max_columns', M) # M개 이하 열일땐 생략하지 않음

# %%
df.groupby('노선명')['승차총승객수'].sum().sort_values(ascending=False).plot(kind='pie', figsize=(10, 10))

# %%
df_pv.plot(kind='box', figsize=(25, 35), subplots=True, layout=(7, 5))
plt.savefig('box plot')
plt.show()

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
x = np.arange(10)
y = x ** 2
plt.plot(x, y, 'rv') # x와 y의 데이터 개수는 일치
plt.xticks([0, 5, 10])  # X축 간격 (눈금)
plt.show()

# %%
# 도화지(Figure) : Cell을 벗어날 수 없음
# 그래프를 한 도화지(Figure)에 여러번 그릴 수 있음 -> X축과 Y축을 공유

# 1) Figure 설정 -> 크기 설정, subplot
plt.figure(figsize=(10, 5)) # (가로, 세로) -> 단위 : 인치

# 2) 그래프 추가 -> plot, bar, scatter, etc 
plt.plot(x, x**2, 'bo', label='y=x^2') # label : 그래프의 이름 지정 -> 범례 
plt.plot(x, x**3, 'g^', label='y=x^3')
plt.plot(x, x**4, 'y+', label='y=x^4')

# 3) 그래프 설정 
plt.xlabel('X축 이름') # X축 이름
plt.ylabel('Y축 이름') # Y축 이름 
plt.title('그래프 제목') # 그래프 제목
plt.legend() # 범례 표시 -> 자동으로 결정 loc로 설정 가능 (upper left)
plt.xticks(np.arange(-3, 13, 3)) # X축의 틱(눈금) 간격
plt.yticks(np.arange(0, 10000, 2000)) # Y축의 틱(눈금) 간격
plt.grid() # 틱을 기준으로 격자 추가
#plt.xlim( (3, 6)) # X축을 3에서 6사이 만 표현 
#plt.ylim() 
plt.savefig('image') # show() 이전에 사용 -> png 
plt.show() # 그래프 출력

# %% [markdown]
# # Seaborn

# %%
# DataFrame -> plot() or seaborn
import seaborn as sns
# sns.함수(data=df, x='컬럼명', y='컬럼명')
tips = sns.load_dataset('tips') # 그래프 시각화를 위한 연습용 데이터 세트 제공
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# # 1) 컬럼명으로 축 지정
#sns.boxplot(data=tips, x='total_bill')

# # 2) 값을 직접 대입
# sns.boxplot(x=tips['total_bill'])

# # X축 : 값 -> 수평
# # Y축 : 값 -> 수직

# # Boxplot -> 연속형 변수 1개, 범주형 변수 1개
#sns.boxplot(data=tips, y='total_bill', x='time') # x값에 따라서 boxplot이 그려짐

# hue : 그래프를 분할하는 역활 
sns.boxplot(data=tips, y='total_bill', x='time', hue='smoker')

# %%
plt.figure(figsize=(8, 8))
sns.lmplot(data=tips, x='total_bill', y='tip', hue='time') # X축, Y축 모두 연속형 변수 -> 실수 -> 상관 관계
# sns.regplot
plt.show()

# %%
# heatmap : 값을 색상으로 표현 -> pivot_table(dataframe)의 결과와 잘 어울림
plt.figure(figsize=(15, 15))
sns.heatmap(df_pv.T / 100, cmap='binary', annot=True, fmt='.2f')
# cmap : 색상 범례 (color bar, cbar=True)
    # jet : (낮) 파-빨 (높)
    # binary : (낮) 흰-검 (높)
    # Greens : 초록색
    # Blues : 파란색
# annot : 숫자 출력 유무 
# fmt : 숫자 형식 
 # d : 정수
 # f : 실수 (6자리) -> .2f (2자리)
plt.show()

# %%
from sklearn.datasets import load_boston
boston = load_boston()
df_boston = pd.DataFrame(boston['data'], columns=boston['feature_names'])
df_boston['target'] = boston['target']
df_boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df_boston.corr(), cmap='Greens', fmt='.2f', annot=True)

# %%
iris = sns.load_dataset('iris')
plt.figure(figsize=(10, 10))
sns.pairplot(data=iris, hue='species') # species -> Y (목표)
plt.show()
# pair : 컬럼과 컬럼의 관계를 시각화 -> 컬럼간의 관계 (산점도, scatter) | 컬럼의 분포 (hist)

# %%
plt.figure(figsize=(10, 10))
sns.pairplot(df_boston)
plt.show()
